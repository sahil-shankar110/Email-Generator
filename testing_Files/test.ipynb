# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv

load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")
llm = ChatGroq(
    api_key=groq_api_key,
    model="meta-llama/llama-4-scout-17b-16e-instruct",
)

response = llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is Paris.

# %%
# Testing Chromadb
import chromadb


client = chromadb.Client()
collection = client.create_collection(name="my_test_collection")

# %%
collection.add(
    documents=["i like apple."],
    ids=["test_id_1"],
    metadatas=[{"source": "test_source"}]
)
# Out:
# C:\Users\khan\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [22:49<00:00, 60.7kiB/s]

# %%
collection.get()
# Out:
# {'ids': ['test_id_1'],
#  'embeddings': None,
#  'documents': ['i like apple.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'source': 'test_source'}]}

# %%
collection.add(
    documents=["i like orange."],
    ids=["test_id_2"],
    metadatas=[{"source": "test_source"}]
)

# %%
collection.get()
# Out:
# {'ids': ['test_id_1', 'test_id_2'],
#  'embeddings': None,
#  'documents': ['i like apple.', 'i like orange.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'source': 'test_source'}, {'source': 'test_source'}]}

# %%
client_2 = chromadb.Client()
collection_2 = client_2.create_collection(name="my_test_collection_2")

# %%
collection_2.add(
    documents=["i like Apple.",
               "i like apple iphone.",
               "i like eating apple."],
    ids=["test_id_1", "test_id_2", "test_id_3"],
    metadatas=[{"source": "test_source_1"},
               {"source": "test_source_2"},
               {"source": "test_source_3"}]
)

# %%
collection_2.get()
# Out:
# {'ids': ['test_id_1', 'test_id_2', 'test_id_3'],
#  'embeddings': None,
#  'documents': ['i like Apple.',
#   'i like apple iphone.',
#   'i like eating apple.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'source': 'test_source_1'},
#   {'source': 'test_source_2'},
#   {'source': 'test_source_3'}]}

# %%
# Querying the collection
collection_2.query(
    query_texts=["i like technology."],
    n_results=2,
)
# Out:
# {'ids': [['test_id_2', 'test_id_1']],
#  'embeddings': None,
#  'documents': [['i like apple iphone.', 'i like Apple.']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'source': 'test_source_2'}, {'source': 'test_source_1'}]],
#  'distances': [[0.8617324829101562, 0.9348669052124023]]}
